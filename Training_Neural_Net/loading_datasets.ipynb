# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import TensorDataset

# %%
df = pd.read_csv("./student_habits_performance.csv")
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
df.iloc[:7,3:7] # row then column
# Out:
#    study_hours_per_day  social_media_hours  netflix_hours part_time_job
# 0                  0.0                 1.2            1.1            No
# 1                  6.9                 2.8            2.3            No
# 2                  1.4                 3.1            1.3            No
# 3                  1.0                 3.9            1.0            No
# 4                  5.0                 4.4            0.5            No
# 5                  7.2                 1.3            0.0            No
# 6                  5.6                 1.5            1.4           Yes

# %%
X = df[["study_hours_per_day","social_media_hours","netflix_hours"]]
y = df[["exam_score"]]
X.head()
# Out:
#    study_hours_per_day  social_media_hours  netflix_hours
# 0                  0.0                 1.2            1.1
# 1                  6.9                 2.8            2.3
# 2                  1.4                 3.1            1.3
# 3                  1.0                 3.9            1.0
# 4                  5.0                 4.4            0.5

# %%
X,y = X.to_numpy(), y.to_numpy()

# %%
dataset = TensorDataset(torch.tensor(X),torch.tensor(y))
dataset

# %%
# Access an individual sample
input_sample, label_sample = dataset[0]
print('input sample:',input_sample)
print('label sample:',label_sample)
# Out:
# input sample: tensor([0.0000, 1.2000, 1.1000], dtype=torch.float64)
# label sample: tensor([56.2000], dtype=torch.float64)

# %%
from torch.utils.data import DataLoader

BATCH_SIZE = 10
SHUFFLE = True

dataloader = DataLoader(dataset=dataset, batch_size=BATCH_SIZE, shuffle=SHUFFLE)

# %%
# Iterate over the dataloader
for batch_inputs, batch_labels in dataloader:
    print('batch inputs:',batch_inputs)
    print('batch labels:',batch_labels)
# Out:
# batch inputs: tensor([[2.0000, 2.8000, 3.3000],
#         [1.2000, 2.3000, 1.7000],
#         [3.6000, 2.5000, 3.0000],
#         [2.9000, 1.9000, 3.2000],
#         [0.9000, 3.3000, 1.6000],
#         [3.5000, 2.1000, 0.5000],
#         [3.4000, 2.7000, 1.2000],
#         [1.2000, 3.6000, 0.0000],
#         [2.8000, 3.1000, 4.5000],
#         [5.1000, 2.9000, 1.6000]], dtype=torch.float64)
# batch labels: tensor([[50.7000],
#         [28.0000],
#         [63.1000],
#         [66.9000],
#         [37.9000],
#         [64.2000],
#         [70.8000],
#         [41.1000],
#         [40.7000],
#         [86.5000]], dtype=torch.float64)
# batch inputs: tensor([[3.3000, 2.2000, 2.9000],
#         [3.3000, 0.7000, 3.6000],
#         [3.3000, 1.9000, 2.2000],
#         [3.1000, 3.6000, 0.4000],
#         [4.1000, 3.8000, 1.9000],
#         [1.7000, 3.3000, 0.6000],
#         [4.7000, 4.1000, 3.0000],
#         [3.8000, 0.7000, 2.1000],
#         [5.1000, 3.9000, 3.0000],
#         [5.0000, 1.3000, 0.8000]], dtype=torch.float64)
# batch labels: tensor([[76.1000],
#         [52.6000],
#         [70.9000],
#         [59.6000],
#         [73.0000],
#         [50.1000],
#         [93.1000],
#         [81.8000],
#         [90.6000],
#         [96.2000]], dtype=torch.float64)
# batch inputs: tensor([[3.6000, 2.2000, 2.2000],
#         [4.8000, 2.1000, 1.9000],
#         [0.8000, 1.4000, 3.8000],
#         [3.9000, 2.4000, 2.5000],
#         [4.6000, 1.5000, 1.8000],
#         [2.6000, 4.0000, 1.1000],
#         [6.2000, 2.7000, 0.9000],
#         [0.0000, 2.0000, 2.5000],
#         [3.8000, 1.7000, 3.8000],
#         [5.3000, 1.8000, 2.0000]], dtype=torch.float64)
# batch labels: tensor([[76.1000],
#         [82.6000],
#         [36.0000],
#         [74.4000],
#         [80.2000],
#         [66.6000],
#         [87.9000],
#         [29.9000],
#         [58.1000],
#         [91.5000]], dtype=torch.float64)
# batch inputs: tensor([[0.8000, 2.3000, 1.0000],
#         [3.1000, 1.1000, 4.1000],
#         [6.8000, 2.9000, 2.0000],
#         [1.6000, 3.3000, 3.5000],
#         [4.2000, 2.0000, 3.5000],
#         [4.8000, 4.3000, 2.1000],
#         [0.0000, 2.8000, 1.6000],
#         [3.6000, 3.0000, 2.0000],
#         [4.3000, 4.9000, 3.0000],
#         [2.1000, 0.9000, 1.5000]], dtype=torch.float64)
# batch labels: tensor([[44.3000],
#         [58.4000],
#         [96.2000],
#         [47.1000],
#         [84.6000],
#         [63.4000],
#         [26.7000],
#         [65.2000],
#         [74.0000],
#         [55.0000]], dtype=torch.float64)
# batch inputs: tensor([[2.1000, 2.3000, 0.9000],
#         [3.8000, 2.4000, 2.2000],
#         [5.8000, 1.4000, 1.9000],
#         [2.9000, 2.6000, 2.0000],
#         [3.0000, 2.5000, 2.6000],
#         [2.4000, 1.9000, 1.5000],
#         [2.4000, 1.9000, 2.1000],
#         [1.7000, 2.9000, 1.6000],
#         [5.3000, 5.0000, 1.8000],
#         [4.1000, 2.0000, 1.0000]], dtype=torch.float64)
# batch labels: tensor([[63.1000],
#         [88.0000],
#         [96.6000],
#         [43.5000],
#         [51.3000],
#         [63.8000],
#         [60.0000],
#         [53.6000],
#         [79.6000],
#         [80.9000]], dtype=torch.float64)
# batch inputs: tensor([[5.4000, 0.2000, 0.0000],
#         [4.7000, 1.8000, 0.2000],
#         [1.8000, 1.8000, 1.1000],
#         [4.0000, 2.3000, 2.5000],
#         [4.1000, 4.2000, 0.0000],
#         [2.3000, 1.1000, 1.8000],
#         [2.8000, 4.1000, 1.7000],
#         [5.8000, 3.2000, 4.1000],
#         [7.2000, 3.7000, 0.0000],
#         [3.9000, 1.1000, 2.9000]], dtype=torch.float64)
# batch labels: tensor([[100.0000],
#         [ 83.3000],
#         [ 48.7000],
#         [ 77.8000],
#         [ 80.4000],
#         [ 66.8000],
#         [ 54.9000],
#         [ 99.3000],
#         [100.0000],
#         [ 75.7000]], dtype=torch.float64)
# batch inputs: tensor([[5.3000, 2.7000, 4.3000],
#         [4.3000, 4.0000, 1.1000],
#         [3.7000, 1.2000, 3.3000],
#         [4.3000, 2.4000, 1.0000],
#         [3.2000, 1.2000, 1.2000],
#         [2.9000, 3.8000, 2.1000],
#         [3.6000, 1.4000, 0.8000],
#         [2.2000, 6.2000, 3.0000],
#         [3.5000, 1.9000, 1.2000],
#         [1.1000, 2.1000, 3.6000]], dtype=torch.float64)
# batch labels: tensor([[74.2000],
#         [59.0000],
#         [82.7000],
#         [88.0000],
#         [81.7000],
#         [52.1000],
#         [78.5000],
#         [46.7000],
#         [92.6000],
#         [50.3000]], dtype=torch.float64)
# batch inputs: tensor([[4.7000, 4.9000, 2.7000],
#         [0.9000, 2.4000, 2.5000],
#         [4.5000, 1.2000, 2.6000],
#         [6.3000, 2.5000, 3.3000],
#         [3.2000, 2.3000, 1.5000],
#         [7.0000, 3.3000, 3.1000],
#         [3.7000, 1.7000, 2.3000],
#         [1.5000, 3.9000, 2.7000],
#         [2.9000, 3.2000, 2.8000],
#         [1.9000, 1.2000, 0.9000]], dtype=torch.float64)
# batch labels: tensor([[89.6000],
#         [23.1000],
#         [76.3000],
#         [95.6000],
#         [64.2000],
#         [94.8000],
#         [75.7000],
#         [42.3000],
#         [63.0000],
#         [56.9000]], dtype=torch.float64)
# batch inputs: tensor([[5.1000, 2.5000, 2.4000],
#         [1.9000, 4.0000, 0.5000],
#         [6.3000, 1.5000, 0.0000],
#         [1.5000, 3.1000, 2.6000],
#         [1.9000, 2.9000, 1.6000],
#         [2.5000, 4.4000, 1.6000],
#         [1.4000, 0.9000, 2.6000],
#         [3.2000, 2.3000, 1.7000],
#         [4.4000, 0.0000, 2.3000],
#         [2.8000, 2.6000, 1.7000]], dtype=torch.float64)
# batch labels: tensor([[ 79.3000],
#         [ 50.4000],
#         [100.0000],
#         [ 51.3000],
#         [ 44.4000],
#         [ 51.3000],
#         [ 51.0000],
#         [ 66.3000],
#         [ 81.9000],
#         [ 70.3000]], dtype=torch.float64)
# batch inputs: tensor([[1.3000, 2.1000, 1.2000],
#         [1.3000, 0.1000, 3.6000],
#         [4.9000, 2.6000, 0.0000],
#         [1.4000, 3.1000, 1.3000],
#         [3.7000, 0.4000, 0.9000],
#         [0.3000, 3.6000, 1.7000],
#         [3.2000, 2.2000, 2.8000],
#         [3.1000, 5.0000, 1.0000],
#         [2.2000, 4.0000, 1.9000],
#         [3.0000, 3.5000, 1.6000]], dtype=torch.float64)
# batch labels: tensor([[46.6000],
#         [44.3000],
#         [80.9000],
#         [34.3000],
#         [87.9000],
#         [33.6000],
#         [71.1000],
#         [74.0000],
#         [47.1000],
#         [54.1000]], dtype=torch.float64)
# batch inputs: tensor([[5.3000, 4.2000, 1.1000],
#         [3.3000, 0.4000, 0.8000],
#         [5.8000, 2.1000, 2.8000],
#         [3.7000, 1.7000, 1.7000],
#         [4.2000, 3.1000, 0.7000],
#         [3.8000, 2.1000, 1.0000],
#         [2.6000, 3.4000, 5.3000],
#         [2.4000, 2.9000, 1.7000],
#         [3.7000, 4.0000, 1.0000],
#         [4.1000, 2.9000, 0.8000]], dtype=torch.float64)
# batch labels: tensor([[83.3000],
#         [82.3000],
#         [96.6000],
#         [80.8000],
#         [79.9000],
#         [70.9000],
#         [49.1000],
#         [67.4000],
#         [77.2000],
#         [76.4000]], dtype=torch.float64)
# batch inputs: tensor([[5.1000, 2.1000, 0.7000],
#         [1.5000, 2.3000, 3.0000],
#         [2.3000, 2.3000, 1.6000],
#         [3.9000, 2.4000, 0.0000],
#         [2.5000, 1.1000, 3.9000],
#         [1.1000, 1.7000, 2.7000],
#         [3.5000, 1.7000, 1.3000],
#         [4.0000, 2.1000, 1.4000],
#         [4.9000, 4.0000, 1.7000],
#         [3.9000, 3.3000, 0.5000]], dtype=torch.float64)
# batch labels: tensor([[99.4000],
#         [54.2000],
#         [68.9000],
#         [59.5000],
#         [58.2000],
#         [35.8000],
#         [73.5000],
#         [82.2000],
#         [77.0000],
#         [64.1000]], dtype=torch.float64)
# batch inputs: tensor([[5.5000, 2.5000, 1.0000],
#         [3.0000, 4.5000, 0.9000],
#         [2.5000, 0.9000, 2.2000],
#         [3.1000, 3.5000, 2.2000],
#         [3.6000, 1.9000, 2.3000],
#         [1.8000, 2.5000, 2.4000],
#         [3.3000, 2.1000, 2.3000],
#         [3.1000, 2.3000, 2.4000],
#         [3.0000, 4.5000, 2.3000],
#         [4.5000, 1.7000, 0.4000]], dtype=torch.float64)
# batch labels: tensor([[80.6000],
#         [51.5000],
#         [58.9000],
#         [49.9000],
#         [83.2000],
#         [45.3000],
#         [67.1000],
#         [61.5000],
#         [52.6000],
#         [71.1000]], dtype=torch.float64)
# batch inputs: tensor([[2.1000, 2.7000, 1.4000],
#         [1.4000, 2.0000, 3.5000],
#         [5.1000, 3.1000, 3.7000],
#         [1.4000, 3.4000, 0.0000],
#         [3.3000, 2.6000, 3.7000],
#         [2.1000, 3.5000, 0.9000],
#         [5.0000, 1.8000, 1.6000],
#         [5.7000, 2.7000, 1.4000],
#         [4.2000, 1.7000, 1.8000],
#         [2.2000, 1.5000, 1.3000]], dtype=torch.float64)
# batch labels: tensor([[39.9000],
#         [41.7000],
#         [85.2000],
#         [55.1000],
#         [61.6000],
#         [63.4000],
#         [92.9000],
#         [89.8000],
#         [76.0000],
#         [71.6000]], dtype=torch.float64)
# batch inputs: tensor([[1.8000, 1.1000, 0.6000],
#         [4.1000, 1.1000, 1.9000],
#         [3.1000, 2.1000, 2.0000],
#         [4.9000, 0.0000, 2.1000],
#         [4.3000, 4.0000, 0.8000],
#         [3.5000, 1.8000, 1.9000],
#         [3.7000, 1.8000, 0.9000],
#         [3.1000, 3.2000, 1.6000],
#         [2.9000, 3.0000, 3.1000],
#         [3.3000, 1.8000, 0.0000]], dtype=torch.float64)
# batch labels: tensor([[70.9000],
#         [80.8000],
#         [53.3000],
#         [94.2000],
#         [60.8000],
#         [85.0000],
#         [56.3000],
#         [65.7000],
#         [59.0000],
#         [65.2000]], dtype=torch.float64)
# batch inputs: tensor([[2.4000, 2.8000, 0.7000],
#         [5.2000, 3.7000, 1.1000],
#         [1.7000, 2.9000, 2.0000],
#         [5.6000, 2.8000, 0.5000],
#         [4.1000, 2.3000, 2.6000],
#         [6.7000, 2.2000, 2.6000],
#         [4.4000, 1.8000, 0.7000],
#         [3.0000, 2.5000, 1.7000],
#         [4.1000, 3.1000, 1.8000],
#         [2.7000, 1.1000, 3.1000]], dtype=torch.float64)
# batch labels: tensor([[ 62.0000],
#         [100.0000],
#         [ 50.2000],
#         [100.0000],
#         [ 77.6000],
#         [ 97.1000],
#         [ 78.4000],
#         [ 70.9000],
#         [ 77.8000],
#         [ 50.8000]], dtype=torch.float64)
# batch inputs: tensor([[1.3000, 0.4000, 2.3000],
#         [3.9000, 1.8000, 3.9000],
#         [3.0000, 3.0000, 1.7000],
#         [3.2000, 3.1000, 2.0000],
#         [5.8000, 3.0000, 0.4000],
#         [8.2000, 2.2000, 1.5000],
#         [4.4000, 3.5000, 2.7000],
#         [3.9000, 2.4000, 1.2000],
#         [2.0000, 0.8000, 0.5000],
#         [3.7000, 3.3000, 2.6000]], dtype=torch.float64)
# batch labels: tensor([[ 42.2000],
#         [ 65.5000],
#         [ 69.8000],
#         [ 70.9000],
#         [ 90.8000],
#         [100.0000],
#         [ 62.4000],
#         [ 75.2000],
#         [ 73.5000],
#         [ 69.2000]], dtype=torch.float64)
# batch inputs: tensor([[5.6000, 1.6000, 0.3000],
#         [3.3000, 3.6000, 2.6000],
#         [3.5000, 2.3000, 2.1000],
#         [2.8000, 2.0000, 4.1000],
#         [2.4000, 2.6000, 1.0000],
#         [2.1000, 1.2000, 3.1000],
#         [2.9000, 1.6000, 1.7000],
#         [3.0000, 2.4000, 4.0000],
#         [2.5000, 2.2000, 2.3000],
#         [2.5000, 2.7000, 1.5000]], dtype=torch.float64)
# batch labels: tensor([[100.0000],
#         [ 57.1000],
#         [ 89.1000],
#         [ 57.3000],
#         [ 48.3000],
#         [ 50.4000],
#         [ 70.2000],
#         [ 62.9000],
#         [ 46.8000],
#         [ 56.1000]], dtype=torch.float64)
# batch inputs: tensor([[1.6000, 3.1000, 2.8000],
#         [3.7000, 2.1000, 0.4000],
#         [3.5000, 1.3000, 1.8000],
#         [3.4000, 0.0000, 1.6000],
#         [2.6000, 0.5000, 1.6000],
#         [4.3000, 3.3000, 2.2000],
#         [3.5000, 3.9000, 2.2000],
#         [3.2000, 2.9000, 2.1000],
#         [4.6000, 2.5000, 3.0000],
#         [4.5000, 2.7000, 1.2000]], dtype=torch.float64)
# batch labels: tensor([[43.5000],
#         [76.9000],
#         [60.0000],
#         [83.4000],
#         [76.1000],
#         [64.6000],
#         [66.8000],
#         [40.3000],
#         [72.7000],
#         [62.9000]], dtype=torch.float64)
# batch inputs: tensor([[1.7000, 3.4000, 3.9000],
#         [5.2000, 1.5000, 0.2000],
#         [3.6000, 2.3000, 2.9000],
#         [3.1000, 3.3000, 1.8000],
#         [4.2000, 3.0000, 0.5000],
#         [4.9000, 2.3000, 0.6000],
#         [4.8000, 2.5000, 2.4000],
#         [4.3000, 2.7000, 2.6000],
#         [3.9000, 1.8000, 3.2000],
#         [4.5000, 3.4000, 3.3000]], dtype=torch.float64)
# batch labels: tensor([[41.7000],
#         [97.9000],
#         [69.6000],
#         [62.7000],
#         [78.4000],
#         [98.7000],
#         [76.2000],
#         [58.4000],
#         [65.6000],
#         [94.7000]], dtype=torch.float64)
# batch inputs: tensor([[0.1000, 1.2000, 0.0000],
#         [4.3000, 3.8000, 1.1000],
#         [2.5000, 1.9000, 1.6000],
#         [2.2000, 3.5000, 1.8000],
#         [2.7000, 1.8000, 0.0000],
#         [3.2000, 2.6000, 2.8000],
#         [6.0000, 3.4000, 2.0000],
#         [2.1000, 2.9000, 1.4000],
#         [2.7000, 2.3000, 3.2000],
#         [2.4000, 0.0000, 3.1000]], dtype=torch.float64)
# batch labels: tensor([[53.4000],
#         [70.9000],
#         [68.5000],
#         [67.6000],
#         [68.2000],
#         [75.4000],
#         [99.9000],
#         [60.4000],
#         [57.4000],
#         [63.9000]], dtype=torch.float64)
# batch inputs: tensor([[2.8000, 2.1000, 0.6000],
#         [1.9000, 3.5000, 1.7000],
#         [2.9000, 2.2000, 1.7000],
#         [3.7000, 0.7000, 0.0000],
#         [5.0000, 2.6000, 3.1000],
#         [0.0000, 0.3000, 1.1000],
#         [4.1000, 1.6000, 0.5000],
#         [3.8000, 1.9000, 3.6000],
#         [3.2000, 3.0000, 1.4000],
#         [2.4000, 2.3000, 2.2000]], dtype=torch.float64)
# batch labels: tensor([[71.0000],
#         [57.7000],
#         [71.2000],
#         [85.1000],
#         [79.6000],
#         [53.3000],
#         [89.8000],
#         [77.8000],
#         [74.8000],
#         [63.9000]], dtype=torch.float64)
# batch inputs: tensor([[6.3000, 3.0000, 1.6000],
#         [3.1000, 3.8000, 2.1000],
#         [3.2000, 1.7000, 2.1000],
#         [3.6000, 3.2000, 2.7000],
#         [3.6000, 1.4000, 2.3000],
#         [1.0000, 1.4000, 2.1000],
#         [2.0000, 3.8000, 1.2000],
#         [4.6000, 2.6000, 1.0000],
#         [3.2000, 2.8000, 4.3000],
#         [5.3000, 2.6000, 0.0000]], dtype=torch.float64)
# batch labels: tensor([[94.8000],
#         [54.1000],
#         [68.6000],
#         [64.5000],
#         [79.2000],
#         [47.6000],
#         [40.4000],
#         [74.6000],
#         [58.6000],
#         [98.4000]], dtype=torch.float64)
# batch inputs: tensor([[3.5000, 2.5000, 1.8000],
#         [2.5000, 3.1000, 1.7000],
#         [4.3000, 3.0000, 1.5000],
#         [2.0000, 0.6000, 3.0000],
#         [3.8000, 4.2000, 1.2000],
#         [3.9000, 2.4000, 1.8000],
#         [3.0000, 3.1000, 2.4000],
#         [3.3000, 2.5000, 2.1000],
#         [4.3000, 2.2000, 2.3000],
#         [4.9000, 2.8000, 0.6000]], dtype=torch.float64)
# batch labels: tensor([[64.5000],
#         [45.1000],
#         [93.2000],
#         [50.5000],
#         [72.3000],
#         [68.4000],
#         [66.3000],
#         [55.4000],
#         [76.0000],
#         [88.7000]], dtype=torch.float64)
# batch inputs: tensor([[3.0000, 4.8000, 2.3000],
#         [3.3000, 2.0000, 1.2000],
#         [5.0000, 2.3000, 0.2000],
#         [2.8000, 3.4000, 0.9000],
#         [5.3000, 1.7000, 1.0000],
#         [4.4000, 4.3000, 3.2000],
#         [3.4000, 2.3000, 2.3000],
#         [3.3000, 2.2000, 0.9000],
#         [4.4000, 2.2000, 0.9000],
#         [3.5000, 1.6000, 2.2000]], dtype=torch.float64)
# batch labels: tensor([[60.6000],
#         [72.2000],
#         [75.4000],
#         [62.6000],
#         [78.4000],
#         [74.6000],
#         [47.6000],
#         [94.0000],
#         [84.2000],
#         [67.7000]], dtype=torch.float64)
# batch inputs: tensor([[3.0000, 0.1000, 1.9000],
#         [4.0000, 3.7000, 2.2000],
#         [2.7000, 2.1000, 1.9000],
#         [5.3000, 1.8000, 3.6000],
#         [2.6000, 2.4000, 2.9000],
#         [2.3000, 3.0000, 4.6000],
#         [5.3000, 2.5000, 2.7000],
#         [5.8000, 2.6000, 0.9000],
#         [4.2000, 4.5000, 3.1000],
#         [0.0000, 3.5000, 3.2000]], dtype=torch.float64)
# batch labels: tensor([[ 82.5000],
#         [ 89.4000],
#         [ 64.5000],
#         [ 71.0000],
#         [ 41.9000],
#         [ 51.8000],
#         [ 93.4000],
#         [100.0000],
#         [ 75.3000],
#         [ 26.2000]], dtype=torch.float64)
# batch inputs: tensor([[3.0000, 1.6000, 2.0000],
#         [3.6000, 2.7000, 0.1000],
#         [4.1000, 3.6000, 2.2000],
#         [6.4000, 4.2000, 1.5000],
#         [3.3000, 4.1000, 0.7000],
#         [6.0000, 1.6000, 1.3000],
#         [4.3000, 4.3000, 1.4000],
#         [0.3000, 3.1000, 1.4000],
#         [4.4000, 1.4000, 2.2000],
#         [6.0000, 2.5000, 2.9000]], dtype=torch.float64)
# batch labels: tensor([[ 67.7000],
#         [ 89.1000],
#         [ 84.0000],
#         [ 85.0000],
#         [ 69.6000],
#         [100.0000],
#         [ 65.2000],
#         [ 36.1000],
#         [ 63.6000],
#         [100.0000]], dtype=torch.float64)
# batch inputs: tensor([[3.0000, 1.8000, 0.7000],
#         [5.1000, 0.9000, 0.7000],
#         [1.6000, 1.3000, 2.9000],
#         [3.6000, 2.4000, 1.4000],
#         [2.5000, 2.8000, 0.5000],
#         [4.7000, 1.8000, 1.7000],
#         [1.8000, 3.1000, 3.1000],
#         [6.4000, 2.7000, 0.3000],
#         [5.9000, 1.3000, 1.7000],
#         [4.9000, 1.6000, 4.0000]], dtype=torch.float64)
# batch labels: tensor([[56.7000],
#         [87.0000],
#         [41.7000],
#         [67.6000],
#         [60.6000],
#         [70.0000],
#         [54.0000],
#         [98.0000],
#         [87.1000],
#         [95.5000]], dtype=torch.float64)
# batch inputs: tensor([[3.4000, 3.0000, 0.1000],
#         [0.8000, 2.3000, 1.3000],
#         [2.0000, 2.2000, 3.2000],
#         [5.3000, 3.2000, 0.0000],
#         [1.9000, 2.1000, 1.3000],
#         [2.4000, 1.5000, 1.4000],
#         [2.7000, 2.9000, 2.9000],
#         [3.3000, 1.7000, 1.8000],
#         [2.8000, 2.2000, 2.7000],
#         [2.8000, 3.3000, 3.3000]], dtype=torch.float64)
# batch labels: tensor([[83.8000],
#         [34.7000],
#         [56.3000],
#         [77.2000],
#         [61.7000],
#         [45.8000],
#         [53.4000],
#         [60.5000],
#         [47.4000],
#         [59.4000]], dtype=torch.float64)
# batch inputs: tensor([[4.4000, 6.1000, 0.0000],
#         [5.4000, 3.1000, 1.8000],
#         [3.2000, 4.2000, 0.7000],
#         [4.0000, 3.3000, 5.4000],
#         [5.5000, 2.7000, 3.2000],
#         [4.1000, 1.9000, 0.2000],
#         [1.7000, 2.0000, 2.4000],
#         [3.1000, 0.7000, 1.3000],
#         [2.4000, 4.1000, 0.0000],
#         [2.2000, 2.4000, 2.3000]], dtype=torch.float64)
# batch labels: tensor([[84.9000],
#         [91.3000],
#         [67.5000],
#         [79.0000],
#         [82.6000],
#         [72.4000],
#         [45.7000],
#         [81.5000],
#         [47.9000],
#         [62.7000]], dtype=torch.float64)
# batch inputs: tensor([[3.2000, 3.5000, 1.7000],
#         [3.5000, 0.0000, 2.4000],
#         [3.5000, 2.1000, 4.9000],
#         [3.1000, 4.0000, 1.3000],
#         [4.0000, 1.4000, 0.0000],
#         [5.3000, 1.2000, 0.8000],
#         [4.0000, 2.0000, 2.0000],
#         [2.6000, 2.2000, 0.0000],
#         [4.9000, 3.0000, 3.6000],
#         [5.6000, 1.4000, 3.1000]], dtype=torch.float64)
# batch labels: tensor([[63.6000],
#         [63.6000],
#         [75.9000],
#         [74.0000],
#         [81.1000],
#         [83.3000],
#         [70.7000],
#         [79.3000],
#         [67.6000],
#         [91.3000]], dtype=torch.float64)
# batch inputs: tensor([[5.4000, 3.3000, 2.6000],
#         [4.6000, 2.2000, 2.6000],
#         [5.0000, 2.9000, 2.6000],
#         [4.3000, 2.7000, 2.4000],
#         [4.6000, 0.6000, 2.1000],
#         [4.3000, 3.7000, 2.5000],
#         [3.5000, 2.1000, 2.3000],
#         [1.7000, 2.6000, 2.6000],
#         [2.6000, 2.9000, 1.1000],
#         [4.9000, 0.3000, 2.7000]], dtype=torch.float64)
# batch labels: tensor([[98.1000],
#         [78.5000],
#         [80.6000],
#         [60.6000],
#         [85.9000],
#         [65.7000],
#         [69.9000],
#         [53.5000],
#         [53.9000],
#         [82.1000]], dtype=torch.float64)
# batch inputs: tensor([[5.2000, 4.0000, 2.4000],
#         [1.9000, 3.1000, 2.0000],
#         [3.7000, 2.9000, 2.8000],
#         [0.8000, 3.9000, 2.4000],
#         [2.6000, 4.9000, 4.3000],
#         [3.5000, 3.9000, 2.6000],
#         [6.2000, 2.8000, 1.0000],
#         [2.0000, 1.3000, 3.4000],
#         [3.4000, 2.2000, 0.4000],
#         [5.8000, 3.5000, 1.9000]], dtype=torch.float64)
# batch labels: tensor([[ 80.6000],
#         [ 53.2000],
#         [ 82.5000],
#         [ 31.5000],
#         [ 52.1000],
#         [ 65.6000],
#         [100.0000],
#         [ 53.8000],
#         [ 71.3000],
#         [ 90.0000]], dtype=torch.float64)
# batch inputs: tensor([[6.7000, 1.4000, 0.9000],
#         [6.6000, 2.6000, 1.5000],
#         [3.4000, 1.5000, 1.0000],
#         [5.6000, 2.8000, 4.1000],
#         [4.6000, 1.8000, 1.6000],
#         [4.9000, 1.3000, 2.8000],
#         [1.8000, 4.8000, 3.2000],
#         [3.2000, 3.2000, 5.0000],
#         [2.6000, 1.6000, 1.3000],
#         [4.8000, 1.9000, 1.1000]], dtype=torch.float64)
# batch labels: tensor([[93.8000],
#         [96.6000],
#         [86.1000],
#         [90.3000],
#         [60.1000],
#         [77.0000],
#         [37.4000],
#         [57.6000],
#         [72.9000],
#         [96.1000]], dtype=torch.float64)
# batch inputs: tensor([[4.9000, 4.4000, 2.9000],
#         [4.1000, 2.6000, 2.4000],
#         [4.2000, 0.3000, 0.1000],
#         [3.8000, 2.4000, 1.1000],
#         [2.6000, 3.3000, 2.4000],
#         [5.1000, 2.6000, 0.9000],
#         [3.4000, 1.5000, 0.7000],
#         [2.3000, 1.9000, 0.0000],
#         [7.3000, 1.7000, 1.6000],
#         [4.3000, 1.3000, 0.0000]], dtype=torch.float64)
# batch labels: tensor([[ 69.4000],
#         [ 85.3000],
#         [100.0000],
#         [ 64.4000],
#         [ 44.5000],
#         [ 96.6000],
#         [ 67.0000],
#         [ 77.4000],
#         [100.0000],
#         [ 90.4000]], dtype=torch.float64)
# batch inputs: tensor([[2.8000, 2.0000, 2.0000],
#         [1.9000, 4.0000, 3.0000],
#         [2.6000, 1.4000, 1.2000],
#         [3.8000, 0.9000, 2.0000],
#         [0.5000, 3.3000, 2.3000],
#         [5.8000, 1.0000, 2.4000],
#         [3.5000, 4.7000, 1.3000],
#         [4.2000, 3.6000, 1.8000],
#         [3.2000, 1.5000, 0.0000],
#         [1.1000, 2.7000, 0.1000]], dtype=torch.float64)
# batch labels: tensor([[ 59.9000],
#         [ 35.7000],
#         [ 80.3000],
#         [ 79.7000],
#         [ 39.0000],
#         [100.0000],
#         [ 55.9000],
#         [ 75.4000],
#         [ 92.0000],
#         [ 51.2000]], dtype=torch.float64)
# batch inputs: tensor([[5.4000, 4.1000, 1.1000],
#         [4.3000, 1.3000, 0.0000],
#         [2.3000, 1.5000, 2.0000],
#         [3.5000, 0.0000, 1.7000],
#         [4.5000, 3.8000, 1.3000],
#         [4.6000, 3.7000, 0.8000],
#         [3.2000, 1.2000, 4.4000],
#         [2.9000, 1.0000, 2.4000],
#         [5.5000, 3.1000, 2.3000],
#         [4.3000, 1.5000, 0.0000]], dtype=torch.float64)
# batch labels: tensor([[69.7000],
#         [84.9000],
#         [57.0000],
#         [70.5000],
#         [74.6000],
#         [63.3000],
#         [77.9000],
#         [65.9000],
#         [82.3000],
#         [84.2000]], dtype=torch.float64)
# batch inputs: tensor([[4.6000, 3.0000, 3.6000],
#         [3.6000, 2.6000, 2.2000],
#         [2.7000, 4.3000, 2.9000],
#         [4.5000, 0.4000, 3.0000],
#         [3.1000, 4.7000, 0.4000],
#         [3.0000, 2.3000, 0.0000],
#         [3.2000, 0.3000, 4.0000],
#         [1.2000, 4.3000, 2.2000],
#         [4.3000, 2.5000, 0.0000],
#         [4.1000, 2.7000, 0.6000]], dtype=torch.float64)
# batch labels: tensor([[66.0000],
#         [61.0000],
#         [53.4000],
#         [91.9000],
#         [71.5000],
#         [77.9000],
#         [43.9000],
#         [36.2000],
#         [59.4000],
#         [67.3000]], dtype=torch.float64)
# batch inputs: tensor([[2.6000, 2.0000, 2.4000],
#         [0.2000, 3.1000, 2.1000],
#         [2.1000, 0.8000, 2.0000],
#         [3.9000, 2.4000, 1.7000],
#         [1.9000, 1.6000, 2.3000],
#         [3.0000, 4.7000, 1.9000],
#         [2.5000, 4.2000, 1.9000],
#         [6.1000, 4.9000, 1.4000],
#         [2.5000, 4.3000, 2.4000],
#         [6.3000, 1.9000, 0.0000]], dtype=torch.float64)
# batch labels: tensor([[ 48.5000],
#         [ 31.5000],
#         [ 68.4000],
#         [ 74.2000],
#         [ 51.2000],
#         [ 61.0000],
#         [ 44.5000],
#         [ 96.1000],
#         [ 49.4000],
#         [100.0000]], dtype=torch.float64)
# batch inputs: tensor([[3.8000, 2.9000, 4.1000],
#         [3.5000, 1.3000, 0.5000],
#         [8.3000, 3.3000, 2.6000],
#         [2.8000, 5.0000, 0.0000],
#         [3.1000, 1.7000, 2.9000],
#         [5.9000, 1.1000, 2.1000],
#         [3.2000, 2.4000, 1.8000],
#         [2.5000, 3.2000, 0.5000],
#         [2.9000, 7.2000, 2.9000],
#         [1.5000, 4.6000, 0.7000]], dtype=torch.float64)
# batch labels: tensor([[ 70.8000],
#         [ 81.9000],
#         [100.0000],
#         [ 71.0000],
#         [ 51.1000],
#         [ 86.4000],
#         [ 76.3000],
#         [ 59.7000],
#         [ 50.1000],
#         [ 45.4000]], dtype=torch.float64)
# batch inputs: tensor([[3.2000, 2.0000, 2.0000],
#         [4.0000, 3.0000, 3.0000],
#         [4.1000, 2.4000, 0.8000],
#         [5.4000, 3.4000, 0.9000],
#         [0.0000, 1.9000, 1.5000],
#         [2.1000, 1.2000, 1.8000],
#         [3.8000, 0.8000, 0.3000],
#         [2.5000, 1.4000, 0.9000],
#         [0.5000, 0.0000, 2.6000],
#         [2.7000, 3.6000, 0.9000]], dtype=torch.float64)
# batch labels: tensor([[65.4000],
#         [74.7000],
#         [66.7000],
#         [92.3000],
#         [55.2000],
#         [66.7000],
#         [71.5000],
#         [73.1000],
#         [45.0000],
#         [67.9000]], dtype=torch.float64)
# batch inputs: tensor([[3.7000, 3.6000, 1.7000],
#         [2.6000, 1.4000, 2.1000],
#         [4.5000, 2.0000, 1.2000],
#         [4.1000, 2.8000, 1.4000],
#         [3.3000, 2.7000, 1.9000],
#         [4.0000, 4.3000, 2.4000],
#         [3.4000, 3.1000, 0.6000],
#         [0.5000, 1.6000, 3.8000],
#         [2.3000, 1.6000, 1.7000],
#         [2.3000, 3.4000, 2.8000]], dtype=torch.float64)
# batch labels: tensor([[77.4000],
#         [63.0000],
#         [84.4000],
#         [60.1000],
#         [66.1000],
#         [53.0000],
#         [74.3000],
#         [30.2000],
#         [56.2000],
#         [40.9000]], dtype=torch.float64)
# batch inputs: tensor([[4.1000, 4.2000, 1.6000],
#         [4.2000, 2.2000, 1.6000],
#         [3.6000, 0.0000, 3.6000],
#         [2.2000, 3.5000, 0.0000],
#         [3.6000, 1.1000, 0.3000],
#         [5.2000, 3.2000, 4.2000],
#         [3.3000, 2.8000, 1.4000],
#         [2.5000, 2.6000, 1.4000],
#         [4.8000, 2.5000, 3.1000],
#         [3.8000, 3.6000, 4.3000]], dtype=torch.float64)
# batch labels: tensor([[57.4000],
#         [73.3000],
#         [66.2000],
#         [57.6000],
#         [77.2000],
#         [83.3000],
#         [71.9000],
#         [52.5000],
#         [83.0000],
#         [69.9000]], dtype=torch.float64)
# batch inputs: tensor([[3.3000, 0.6000, 1.2000],
#         [2.3000, 1.9000, 0.1000],
#         [2.0000, 1.7000, 0.2000],
#         [1.8000, 1.7000, 0.3000],
#         [3.8000, 3.3000, 2.5000],
#         [5.7000, 3.1000, 0.0000],
#         [4.5000, 4.9000, 0.8000],
#         [4.5000, 3.2000, 3.3000],
#         [4.8000, 2.7000, 2.3000],
#         [4.9000, 0.0000, 2.5000]], dtype=torch.float64)
# batch labels: tensor([[73.0000],
#         [61.7000],
#         [66.5000],
#         [58.1000],
#         [74.3000],
#         [80.9000],
#         [72.2000],
#         [59.9000],
#         [70.8000],
#         [97.2000]], dtype=torch.float64)
# batch inputs: tensor([[3.9000, 1.8000, 2.1000],
#         [2.6000, 1.8000, 3.0000],
#         [4.3000, 2.2000, 1.6000],
#         [4.9000, 4.4000, 1.4000],
#         [2.5000, 1.7000, 4.1000],
#         [2.9000, 4.6000, 0.0000],
#         [4.0000, 3.2000, 1.7000],
#         [4.9000, 3.3000, 3.0000],
#         [5.1000, 3.9000, 1.7000],
#         [3.9000, 3.3000, 1.1000]], dtype=torch.float64)
# batch labels: tensor([[64.4000],
#         [62.3000],
#         [88.0000],
#         [77.2000],
#         [65.0000],
#         [67.8000],
#         [68.4000],
#         [71.8000],
#         [65.1000],
#         [56.0000]], dtype=torch.float64)
# batch inputs: tensor([[1.7000, 3.8000, 1.2000],
#         [4.2000, 1.2000, 4.0000],
#         [3.1000, 2.8000, 2.2000],
#         [4.9000, 3.5000, 1.2000],
#         [2.4000, 2.9000, 0.5000],
#         [4.4000, 2.2000, 1.7000],
#         [3.0000, 1.4000, 2.0000],
#         [6.0000, 2.2000, 2.8000],
#         [4.0000, 1.4000, 1.3000],
#         [6.7000, 2.9000, 2.0000]], dtype=torch.float64)
# batch labels: tensor([[ 55.4000],
#         [ 85.3000],
#         [ 74.1000],
#         [ 75.4000],
#         [ 50.4000],
#         [ 78.9000],
#         [ 67.2000],
#         [ 96.8000],
#         [ 75.9000],
#         [100.0000]], dtype=torch.float64)
# batch inputs: tensor([[2.0000, 4.9000, 2.9000],
#         [2.9000, 3.6000, 1.2000],
#         [4.6000, 3.9000, 0.0000],
#         [5.3000, 2.2000, 1.7000],
#         [4.3000, 1.9000, 1.9000],
#         [4.3000, 3.4000, 0.9000],
#         [2.9000, 1.1000, 2.8000],
#         [2.3000, 2.9000, 1.0000],
#         [3.9000, 1.9000, 0.2000],
#         [4.6000, 1.4000, 2.9000]], dtype=torch.float64)
# batch labels: tensor([[43.9000],
#         [45.9000],
#         [84.8000],
#         [93.1000],
#         [82.9000],
#         [59.2000],
#         [68.4000],
#         [48.9000],
#         [93.5000],
#         [85.6000]], dtype=torch.float64)
# batch inputs: tensor([[5.4000, 2.8000, 3.8000],
#         [4.9000, 4.3000, 3.3000],
#         [4.5000, 4.4000, 2.2000],
#         [4.9000, 1.9000, 2.5000],
#         [3.2000, 2.3000, 1.5000],
#         [3.5000, 0.0000, 2.3000],
#         [5.3000, 3.8000, 1.7000],
#         [6.5000, 3.5000, 3.9000],
#         [4.4000, 3.4000, 1.4000],
#         [3.7000, 3.6000, 3.3000]], dtype=torch.float64)
# batch labels: tensor([[ 87.2000],
#         [ 69.9000],
#         [ 64.0000],
#         [ 98.7000],
#         [ 59.6000],
#         [ 64.4000],
#         [ 96.3000],
#         [100.0000],
#         [ 69.1000],
#         [ 69.3000]], dtype=torch.float64)
# batch inputs: tensor([[2.6000, 2.2000, 0.7000],
#         [0.0000, 1.4000, 0.0000],
#         [2.7000, 4.7000, 1.7000],
#         [4.5000, 1.4000, 1.5000],
#         [2.3000, 4.6000, 0.6000],
#         [3.9000, 3.4000, 3.2000],
#         [3.2000, 2.0000, 1.6000],
#         [2.5000, 1.9000, 3.2000],
#         [2.9000, 2.8000, 0.5000],
#         [4.1000, 1.6000, 0.6000]], dtype=torch.float64)
# batch labels: tensor([[63.6000],
#         [50.1000],
#         [59.3000],
#         [83.7000],
#         [58.7000],
#         [77.0000],
#         [60.5000],
#         [60.1000],
#         [61.6000],
#         [77.5000]], dtype=torch.float64)
# batch inputs: tensor([[3.7000, 2.8000, 3.6000],
#         [3.5000, 3.1000, 0.0000],
#         [2.3000, 0.4000, 2.0000],
#         [2.8000, 1.4000, 3.1000],
#         [3.0000, 3.0000, 1.6000],
#         [4.1000, 4.6000, 3.4000],
#         [2.5000, 2.0000, 0.0000],
#         [1.6000, 3.2000, 1.7000],
#         [3.6000, 2.1000, 3.5000],
#         [3.5000, 0.9000, 0.4000]], dtype=torch.float64)
# batch labels: tensor([[59.8000],
#         [75.5000],
#         [70.3000],
#         [63.7000],
#         [63.2000],
#         [81.6000],
#         [66.7000],
#         [36.8000],
#         [65.6000],
#         [72.9000]], dtype=torch.float64)
# batch inputs: tensor([[4.3000, 0.9000, 3.2000],
#         [5.6000, 1.5000, 1.4000],
#         [0.7000, 3.4000, 1.4000],
#         [3.9000, 1.6000, 1.2000],
#         [2.3000, 2.3000, 1.7000],
#         [3.3000, 2.8000, 0.0000],
#         [1.5000, 1.4000, 2.4000],
#         [3.2000, 0.2000, 0.9000],
#         [4.2000, 3.4000, 1.4000],
#         [0.7000, 3.2000, 0.3000]], dtype=torch.float64)
# batch labels: tensor([[65.7000],
#         [89.8000],
#         [42.4000],
#         [74.3000],
#         [58.5000],
#         [70.6000],
#         [46.2000],
#         [76.1000],
#         [74.0000],
#         [47.2000]], dtype=torch.float64)
# batch inputs: tensor([[4.9000, 2.8000, 1.6000],
#         [6.2000, 1.0000, 3.4000],
#         [2.6000, 2.3000, 0.9000],
#         [7.4000, 3.6000, 3.9000],
#         [2.4000, 3.7000, 2.0000],
#         [3.5000, 2.3000, 2.2000],
#         [3.2000, 3.1000, 2.0000],
#         [1.9000, 3.0000, 2.3000],
#         [4.1000, 2.1000, 2.4000],
#         [3.6000, 3.6000, 0.9000]], dtype=torch.float64)
# batch labels: tensor([[ 85.0000],
#         [100.0000],
#         [ 69.3000],
#         [ 97.7000],
#         [ 52.4000],
#         [ 78.1000],
#         [ 74.5000],
#         [ 43.3000],
#         [ 83.1000],
#         [ 72.9000]], dtype=torch.float64)
# batch inputs: tensor([[3.5000, 3.0000, 2.6000],
#         [2.8000, 2.4000, 0.7000],
#         [4.7000, 1.3000, 3.3000],
#         [5.1000, 1.5000, 0.8000],
#         [5.3000, 2.4000, 0.1000],
#         [3.1000, 2.2000, 2.5000],
#         [2.0000, 0.0000, 3.1000],
#         [3.8000, 1.7000, 1.4000],
#         [2.7000, 2.9000, 1.7000],
#         [1.3000, 3.4000, 2.2000]], dtype=torch.float64)
# batch labels: tensor([[70.7000],
#         [61.5000],
#         [73.6000],
#         [83.2000],
#         [85.8000],
#         [66.9000],
#         [58.3000],
#         [58.1000],
#         [46.6000],
#         [49.7000]], dtype=torch.float64)
# batch inputs: tensor([[3.8000, 3.0000, 0.7000],
#         [5.3000, 2.9000, 0.9000],
#         [3.7000, 3.5000, 2.5000],
#         [2.4000, 2.8000, 0.9000],
#         [1.4000, 2.1000, 2.8000],
#         [3.5000, 3.0000, 2.7000],
#         [4.3000, 3.3000, 2.3000],
#         [3.7000, 4.5000, 2.2000],
#         [4.0000, 1.7000, 2.6000],
#         [2.5000, 2.9000, 2.7000]], dtype=torch.float64)
# batch labels: tensor([[61.6000],
#         [84.1000],
#         [81.0000],
#         [54.7000],
#         [52.6000],
#         [66.7000],
#         [69.4000],
#         [73.8000],
#         [75.0000],
#         [59.7000]], dtype=torch.float64)
# batch inputs: tensor([[4.3000, 3.1000, 0.7000],
#         [0.0000, 4.6000, 2.0000],
#         [4.6000, 1.8000, 1.5000],
#         [3.6000, 1.5000, 0.5000],
#         [1.7000, 1.2000, 3.2000],
#         [1.4000, 4.0000, 3.6000],
#         [3.7000, 3.3000, 0.3000],
#         [2.5000, 3.7000, 1.2000],
#         [4.0000, 0.7000, 3.1000],
#         [2.6000, 5.4000, 3.3000]], dtype=torch.float64)
# batch labels: tensor([[81.4000],
#         [43.4000],
#         [94.2000],
#         [70.7000],
#         [37.4000],
#         [35.4000],
#         [72.3000],
#         [78.8000],
#         [83.5000],
#         [59.8000]], dtype=torch.float64)
# batch inputs: tensor([[3.4000, 2.7000, 2.7000],
#         [1.4000, 2.7000, 3.4000],
#         [4.4000, 2.0000, 2.0000],
#         [4.6000, 1.8000, 3.0000],
#         [1.2000, 1.1000, 0.7000],
#         [1.6000, 1.8000, 0.0000],
#         [1.6000, 1.0000, 3.1000],
#         [5.5000, 3.6000, 0.0000],
#         [4.8000, 1.5000, 2.2000],
#         [4.1000, 1.9000, 2.6000]], dtype=torch.float64)
# batch labels: tensor([[75.8000],
#         [29.7000],
#         [77.3000],
#         [86.2000],
#         [35.6000],
#         [58.6000],
#         [62.0000],
#         [80.3000],
#         [78.4000],
#         [91.9000]], dtype=torch.float64)
# batch inputs: tensor([[2.0000, 2.4000, 3.9000],
#         [5.2000, 3.7000, 0.9000],
#         [3.5000, 3.3000, 1.4000],
#         [3.0000, 2.6000, 1.6000],
#         [4.4000, 0.2000, 1.4000],
#         [2.3000, 3.2000, 2.4000],
#         [3.6000, 2.0000, 1.0000],
#         [3.6000, 4.2000, 0.9000],
#         [1.2000, 1.3000, 2.0000],
#         [4.6000, 3.4000, 2.0000]], dtype=torch.float64)
# batch labels: tensor([[29.5000],
#         [77.1000],
#         [65.0000],
#         [55.0000],
#         [80.7000],
#         [48.5000],
#         [85.6000],
#         [66.5000],
#         [49.4000],
#         [71.8000]], dtype=torch.float64)
# batch inputs: tensor([[6.3000, 3.0000, 3.9000],
#         [4.8000, 1.8000, 2.7000],
#         [1.7000, 3.5000, 2.5000],
#         [2.4000, 1.5000, 0.7000],
#         [3.8000, 2.5000, 1.8000],
#         [0.8000, 2.4000, 0.8000],
#         [5.3000, 1.9000, 3.2000],
#         [3.6000, 4.0000, 0.5000],
#         [2.2000, 4.5000, 3.3000],
#         [5.9000, 4.6000, 2.6000]], dtype=torch.float64)
# batch labels: tensor([[85.3000],
#         [88.0000],
#         [53.0000],
#         [78.9000],
#         [76.8000],
#         [35.3000],
#         [85.7000],
#         [53.2000],
#         [50.2000],
#         [72.7000]], dtype=torch.float64)
# batch inputs: tensor([[1.0000, 0.6000, 0.2000],
#         [4.5000, 4.6000, 2.0000],
#         [1.8000, 1.1000, 0.3000],
#         [3.2000, 2.1000, 2.1000],
#         [6.6000, 2.2000, 2.7000],
#         [3.3000, 3.0000, 1.0000],
#         [3.5000, 3.6000, 2.2000],
#         [3.9000, 2.9000, 2.0000],
#         [4.5000, 6.0000, 2.2000],
#         [3.2000, 3.0000, 0.1000]], dtype=torch.float64)
# batch labels: tensor([[ 55.2000],
#         [ 73.8000],
#         [ 49.8000],
#         [ 69.4000],
#         [100.0000],
#         [ 73.0000],
#         [ 75.1000],
#         [ 71.0000],
#         [ 73.7000],
#         [ 82.4000]], dtype=torch.float64)
# batch inputs: tensor([[3.5000, 3.0000, 1.5000],
#         [3.3000, 2.1000, 2.1000],
#         [3.2000, 4.0000, 2.7000],
#         [5.4000, 1.6000, 1.4000],
#         [5.1000, 3.1000, 0.5000],
#         [4.5000, 1.6000, 2.9000],
#         [3.2000, 1.7000, 2.1000],
#         [4.5000, 3.8000, 2.5000],
#         [3.1000, 2.1000, 3.0000],
#         [3.3000, 2.9000, 3.6000]], dtype=torch.float64)
# batch labels: tensor([[67.4000],
#         [71.4000],
#         [61.8000],
#         [95.5000],
#         [76.0000],
#         [71.3000],
#         [66.3000],
#         [66.1000],
#         [85.6000],
#         [60.3000]], dtype=torch.float64)
# batch inputs: tensor([[2.4000, 2.6000, 1.5000],
#         [2.8000, 1.4000, 2.8000],
#         [5.5000, 3.0000, 1.4000],
#         [2.1000, 1.9000, 2.7000],
#         [4.8000, 2.8000, 0.6000],
#         [3.5000, 3.6000, 2.7000],
#         [4.3000, 3.2000, 2.8000],
#         [4.2000, 3.0000, 2.1000],
#         [2.0000, 1.6000, 0.0000],
#         [7.1000, 1.9000, 1.1000]], dtype=torch.float64)
# batch labels: tensor([[ 58.9000],
#         [ 73.0000],
#         [ 76.3000],
#         [ 62.5000],
#         [ 85.4000],
#         [ 72.6000],
#         [ 67.5000],
#         [ 64.2000],
#         [ 49.1000],
#         [100.0000]], dtype=torch.float64)
# batch inputs: tensor([[4.6000, 0.9000, 1.9000],
#         [3.3000, 2.9000, 2.3000],
#         [3.6000, 3.1000, 1.1000],
#         [0.0000, 2.6000, 1.6000],
#         [3.4000, 2.5000, 2.2000],
#         [1.1000, 4.3000, 0.9000],
#         [5.7000, 3.8000, 0.0000],
#         [2.0000, 4.4000, 1.8000],
#         [3.7000, 3.1000, 3.4000],
#         [3.3000, 1.6000, 1.9000]], dtype=torch.float64)
# batch labels: tensor([[ 81.3000],
#         [ 81.1000],
#         [ 75.1000],
#         [ 32.9000],
#         [ 63.4000],
#         [ 49.9000],
#         [100.0000],
#         [ 51.5000],
#         [ 59.8000],
#         [ 70.1000]], dtype=torch.float64)
# batch inputs: tensor([[3.2000, 3.8000, 2.3000],
#         [2.2000, 4.7000, 2.2000],
#         [0.3000, 4.2000, 1.5000],
#         [2.5000, 3.2000, 2.0000],
#         [1.1000, 0.4000, 2.4000],
#         [6.6000, 3.2000, 2.1000],
#         [2.8000, 2.2000, 1.5000],
#         [4.6000, 2.0000, 3.6000],
#         [5.0000, 4.4000, 0.5000],
#         [3.5000, 2.1000, 1.4000]], dtype=torch.float64)
# batch labels: tensor([[ 76.1000],
#         [ 45.2000],
#         [ 26.8000],
#         [ 41.6000],
#         [ 46.3000],
#         [100.0000],
#         [ 74.7000],
#         [ 83.0000],
#         [ 66.4000],
#         [ 64.2000]], dtype=torch.float64)
# batch inputs: tensor([[6.9000, 2.8000, 2.3000],
#         [2.0000, 3.5000, 2.6000],
#         [3.8000, 4.9000, 1.9000],
#         [4.3000, 2.9000, 1.9000],
#         [0.0000, 3.8000, 1.3000],
#         [6.0000, 3.3000, 2.2000],
#         [5.6000, 2.4000, 2.3000],
#         [4.7000, 4.3000, 0.0000],
#         [5.0000, 3.4000, 1.6000],
#         [3.1000, 2.0000, 1.9000]], dtype=torch.float64)
# batch labels: tensor([[100.0000],
#         [ 53.2000],
#         [ 65.5000],
#         [ 74.9000],
#         [ 31.1000],
#         [ 90.2000],
#         [100.0000],
#         [ 83.5000],
#         [ 67.7000],
#         [ 65.4000]], dtype=torch.float64)
# batch inputs: tensor([[3.7000, 4.7000, 2.0000],
#         [4.2000, 2.9000, 2.5000],
#         [4.2000, 2.2000, 0.3000],
#         [2.7000, 1.9000, 2.3000],
#         [6.5000, 0.7000, 1.7000],
#         [0.7000, 2.2000, 0.0000],
#         [3.8000, 2.3000, 2.9000],
#         [4.7000, 2.5000, 1.5000],
#         [2.1000, 3.1000, 4.2000],
#         [4.7000, 4.7000, 2.3000]], dtype=torch.float64)
# batch labels: tensor([[ 69.7000],
#         [ 60.4000],
#         [ 87.5000],
#         [ 71.2000],
#         [100.0000],
#         [ 48.7000],
#         [ 58.5000],
#         [ 78.0000],
#         [ 50.1000],
#         [ 69.7000]], dtype=torch.float64)
# batch inputs: tensor([[4.2000, 4.5000, 2.1000],
#         [1.7000, 1.6000, 1.7000],
#         [5.4000, 2.4000, 2.5000],
#         [3.8000, 3.3000, 1.9000],
#         [2.3000, 0.6000, 1.1000],
#         [4.8000, 2.9000, 2.6000],
#         [5.2000, 4.2000, 2.8000],
#         [6.0000, 2.1000, 3.0000],
#         [3.8000, 0.6000, 1.0000],
#         [4.8000, 2.0000, 3.5000]], dtype=torch.float64)
# batch labels: tensor([[70.6000],
#         [67.9000],
#         [77.5000],
#         [58.3000],
#         [73.5000],
#         [82.1000],
#         [77.9000],
#         [85.3000],
#         [85.7000],
#         [70.6000]], dtype=torch.float64)
# batch inputs: tensor([[4.6000, 3.7000, 0.6000],
#         [3.4000, 5.7000, 0.0000],
#         [5.7000, 2.1000, 2.4000],
#         [4.4000, 2.9000, 1.4000],
#         [4.5000, 2.4000, 1.2000],
#         [4.7000, 3.1000, 0.9000],
#         [0.8000, 3.3000, 0.2000],
#         [4.6000, 3.2000, 1.3000],
#         [4.0000, 3.4000, 3.4000],
#         [3.0000, 3.7000, 0.9000]], dtype=torch.float64)
# batch labels: tensor([[73.2000],
#         [74.7000],
#         [83.8000],
#         [77.9000],
#         [79.0000],
#         [96.4000],
#         [51.8000],
#         [77.6000],
#         [68.8000],
#         [73.9000]], dtype=torch.float64)
# batch inputs: tensor([[3.3000, 4.3000, 0.4000],
#         [2.5000, 1.8000, 1.2000],
#         [4.8000, 2.3000, 1.6000],
#         [6.1000, 1.5000, 0.4000],
#         [5.9000, 0.0000, 2.0000],
#         [2.7000, 3.7000, 2.3000],
#         [1.7000, 2.1000, 0.6000],
#         [4.3000, 2.3000, 1.2000],
#         [2.1000, 2.1000, 2.0000],
#         [3.3000, 4.3000, 3.9000]], dtype=torch.float64)
# batch labels: tensor([[ 67.0000],
#         [ 70.5000],
#         [ 89.3000],
#         [100.0000],
#         [100.0000],
#         [ 63.9000],
#         [ 61.2000],
#         [ 77.4000],
#         [ 44.1000],
#         [ 56.4000]], dtype=torch.float64)
# batch inputs: tensor([[3.8000, 4.1000, 1.6000],
#         [1.7000, 0.2000, 0.8000],
#         [6.8000, 2.5000, 0.7000],
#         [4.0000, 3.2000, 2.3000],
#         [1.7000, 2.9000, 2.5000],
#         [3.0000, 2.6000, 1.3000],
#         [3.2000, 3.2000, 2.6000],
#         [4.4000, 4.3000, 0.0000],
#         [4.9000, 1.5000, 3.4000],
#         [4.1000, 3.3000, 0.6000]], dtype=torch.float64)
# batch labels: tensor([[81.0000],
#         [56.4000],
#         [93.1000],
#         [63.0000],
#         [39.9000],
#         [64.4000],
#         [46.7000],
#         [70.1000],
#         [88.2000],
#         [62.7000]], dtype=torch.float64)
# batch inputs: tensor([[2.8000, 4.2000, 0.9000],
#         [1.9000, 0.7000, 0.0000],
#         [4.6000, 0.5000, 1.6000],
#         [5.4000, 3.0000, 1.5000],
#         [2.2000, 3.1000, 1.1000],
#         [6.0000, 3.6000, 0.8000],
#         [2.3000, 0.9000, 1.0000],
#         [2.5000, 2.1000, 1.5000],
#         [2.6000, 5.3000, 1.7000],
#         [1.5000, 2.4000, 2.0000]], dtype=torch.float64)
# batch labels: tensor([[59.7000],
#         [51.5000],
#         [88.9000],
#         [94.5000],
#         [33.8000],
#         [87.9000],
#         [47.2000],
#         [60.3000],
#         [67.0000],
#         [60.3000]], dtype=torch.float64)
# batch inputs: tensor([[0.0000, 2.4000, 2.9000],
#         [2.3000, 2.1000, 1.8000],
#         [2.2000, 1.0000, 2.9000],
#         [2.7000, 2.5000, 1.4000],
#         [0.7000, 3.2000, 2.4000],
#         [5.2000, 3.8000, 2.8000],
#         [3.8000, 3.1000, 2.3000],
#         [3.8000, 2.0000, 1.4000],
#         [3.9000, 1.6000, 0.7000],
#         [6.0000, 1.6000, 1.3000]], dtype=torch.float64)
# batch labels: tensor([[ 30.5000],
#         [ 54.7000],
#         [ 63.7000],
#         [ 52.2000],
#         [ 50.3000],
#         [ 72.0000],
#         [ 67.8000],
#         [ 65.9000],
#         [ 68.7000],
#         [100.0000]], dtype=torch.float64)
# batch inputs: tensor([[5.6000, 2.1000, 2.4000],
#         [4.2000, 1.7000, 0.0000],
#         [4.4000, 1.9000, 0.8000],
#         [1.4000, 3.9000, 3.9000],
#         [0.8000, 3.2000, 1.4000],
#         [0.3000, 3.2000, 2.2000],
#         [5.0000, 1.5000, 2.2000],
#         [3.3000, 1.5000, 1.8000],
#         [3.8000, 0.9000, 1.0000],
#         [2.6000, 4.9000, 0.0000]], dtype=torch.float64)
# batch labels: tensor([[82.5000],
#         [72.6000],
#         [76.9000],
#         [32.8000],
#         [45.1000],
#         [34.0000],
#         [83.6000],
#         [62.6000],
#         [80.9000],
#         [60.2000]], dtype=torch.float64)
# batch inputs: tensor([[2.7000, 1.4000, 2.8000],
#         [3.0000, 0.0000, 0.6000],
#         [4.0000, 1.8000, 3.4000],
#         [7.5000, 3.6000, 1.9000],
#         [4.3000, 2.6000, 1.2000],
#         [5.5000, 1.1000, 1.4000],
#         [3.7000, 2.8000, 2.1000],
#         [6.6000, 1.3000, 1.7000],
#         [2.1000, 2.1000, 3.6000],
#         [2.9000, 2.3000, 2.3000]], dtype=torch.float64)
# batch labels: tensor([[ 63.5000],
#         [ 98.7000],
#         [ 82.9000],
#         [100.0000],
#         [ 87.5000],
#         [ 84.5000],
#         [ 75.5000],
#         [ 97.7000],
#         [ 56.9000],
#         [ 66.0000]], dtype=torch.float64)
# batch inputs: tensor([[4.7000, 3.2000, 3.1000],
#         [3.6000, 2.0000, 0.1000],
#         [4.1000, 2.5000, 3.0000],
#         [7.2000, 1.3000, 0.0000],
#         [3.5000, 1.3000, 2.1000],
#         [3.5000, 3.1000, 2.9000],
#         [0.0000, 2.4000, 0.6000],
#         [4.7000, 1.8000, 1.6000],
#         [2.3000, 1.5000, 3.2000],
#         [3.2000, 4.5000, 0.7000]], dtype=torch.float64)
# batch labels: tensor([[ 80.3000],
#         [ 66.8000],
#         [ 70.2000],
#         [100.0000],
#         [ 60.4000],
#         [ 55.1000],
#         [ 53.0000],
#         [ 81.1000],
#         [ 52.4000],
#         [ 45.7000]], dtype=torch.float64)
# batch inputs: tensor([[4.0000, 3.4000, 3.2000],
#         [2.9000, 2.4000, 0.0000],
#         [2.0000, 1.2000, 2.7000],
#         [6.1000, 1.9000, 0.2000],
#         [0.0000, 1.2000, 1.1000],
#         [3.7000, 3.9000, 2.2000],
#         [3.3000, 2.9000, 1.1000],
#         [1.9000, 3.2000, 1.2000],
#         [3.8000, 0.9000, 2.5000],
#         [4.3000, 0.9000, 1.2000]], dtype=torch.float64)
# batch labels: tensor([[61.7000],
#         [61.4000],
#         [55.4000],
#         [98.5000],
#         [56.2000],
#         [66.6000],
#         [70.4000],
#         [41.7000],
#         [78.1000],
#         [72.6000]], dtype=torch.float64)
# batch inputs: tensor([[5.8000, 0.6000, 1.6000],
#         [4.6000, 2.4000, 2.4000],
#         [3.8000, 3.0000, 3.4000],
#         [3.3000, 1.4000, 0.4000],
#         [4.5000, 3.4000, 0.4000],
#         [3.4000, 3.1000, 1.4000],
#         [3.4000, 3.6000, 3.1000],
#         [1.4000, 3.5000, 1.6000],
#         [3.9000, 3.9000, 1.0000],
#         [2.4000, 4.3000, 1.0000]], dtype=torch.float64)
# batch labels: tensor([[100.0000],
#         [ 87.8000],
#         [ 61.5000],
#         [ 72.9000],
#         [ 98.8000],
#         [ 75.2000],
#         [ 76.4000],
#         [ 39.8000],
#         [ 71.5000],
#         [ 71.0000]], dtype=torch.float64)
# batch inputs: tensor([[5.1000, 2.6000, 1.8000],
#         [2.4000, 3.2000, 3.7000],
#         [1.4000, 3.3000, 2.5000],
#         [5.2000, 2.8000, 3.2000],
#         [4.6000, 1.2000, 0.5000],
#         [2.7000, 1.7000, 1.3000],
#         [2.0000, 2.7000, 2.0000],
#         [2.2000, 1.0000, 1.4000],
#         [4.1000, 2.5000, 1.9000],
#         [4.3000, 1.1000, 2.0000]], dtype=torch.float64)
# batch labels: tensor([[100.0000],
#         [ 47.0000],
#         [ 46.5000],
#         [ 89.5000],
#         [ 93.0000],
#         [ 59.7000],
#         [ 71.7000],
#         [ 62.6000],
#         [ 75.4000],
#         [ 71.4000]], dtype=torch.float64)
# batch inputs: tensor([[2.5000, 3.8000, 2.2000],
#         [7.6000, 3.0000, 2.9000],
#         [2.5000, 0.8000, 2.0000],
#         [3.1000, 0.0000, 3.3000],
#         [1.2000, 2.5000, 0.8000],
#         [5.0000, 4.0000, 1.4000],
#         [3.3000, 2.0000, 2.1000],
#         [4.3000, 3.3000, 0.0000],
#         [2.6000, 3.5000, 2.0000],
#         [5.1000, 0.5000, 1.4000]], dtype=torch.float64)
# batch labels: tensor([[ 63.4000],
#         [100.0000],
#         [ 75.6000],
#         [ 72.8000],
#         [ 50.3000],
#         [ 88.6000],
#         [ 75.4000],
#         [ 94.9000],
#         [ 39.6000],
#         [100.0000]], dtype=torch.float64)
# batch inputs: tensor([[2.7000, 2.4000, 2.7000],
#         [3.5000, 0.8000, 0.6000],
#         [3.7000, 1.9000, 2.5000],
#         [2.0000, 0.8000, 2.6000],
#         [3.4000, 0.5000, 0.4000],
#         [5.7000, 0.9000, 1.2000],
#         [5.9000, 4.6000, 0.9000],
#         [4.5000, 3.1000, 0.5000],
#         [3.7000, 1.8000, 1.3000],
#         [5.9000, 3.3000, 2.8000]], dtype=torch.float64)
# batch labels: tensor([[ 58.8000],
#         [ 84.2000],
#         [ 61.1000],
#         [ 45.2000],
#         [ 78.0000],
#         [100.0000],
#         [100.0000],
#         [ 93.8000],
#         [ 80.9000],
#         [ 91.6000]], dtype=torch.float64)
# batch inputs: tensor([[2.0000, 3.2000, 3.8000],
#         [5.6000, 2.0000, 0.0000],
#         [0.9000, 4.3000, 4.1000],
#         [4.1000, 5.4000, 0.9000],
#         [3.6000, 3.0000, 1.9000],
#         [1.7000, 1.0000, 1.7000],
#         [4.5000, 0.9000, 2.2000],
#         [4.4000, 0.9000, 0.0000],
#         [3.5000, 3.2000, 2.4000],
#         [3.1000, 1.9000, 2.6000]], dtype=torch.float64)
# batch labels: tensor([[ 75.7000],
#         [100.0000],
#         [ 27.6000],
#         [ 73.2000],
#         [ 74.0000],
#         [ 63.6000],
#         [ 70.6000],
#         [ 96.5000],
#         [ 75.5000],
#         [ 68.1000]], dtype=torch.float64)
# batch inputs: tensor([[4.6000, 1.2000, 0.0000],
#         [3.6000, 0.9000, 2.4000],
#         [2.9000, 2.3000, 0.8000],
#         [2.3000, 2.5000, 1.9000],
#         [3.9000, 2.2000, 0.2000],
#         [3.5000, 5.2000, 0.7000],
#         [4.3000, 4.8000, 2.9000],
#         [0.5000, 0.8000, 2.5000],
#         [5.0000, 2.8000, 0.0000],
#         [4.3000, 1.0000, 2.0000]], dtype=torch.float64)
# batch labels: tensor([[91.7000],
#         [72.3000],
#         [75.1000],
#         [71.9000],
#         [84.9000],
#         [53.4000],
#         [79.8000],
#         [43.9000],
#         [83.5000],
#         [72.6000]], dtype=torch.float64)
# batch inputs: tensor([[5.7000, 2.9000, 1.7000],
#         [2.2000, 0.9000, 3.1000],
#         [5.3000, 2.7000, 2.4000],
#         [7.4000, 3.6000, 1.3000],
#         [2.8000, 0.2000, 3.1000],
#         [5.1000, 1.5000, 3.2000],
#         [3.8000, 2.0000, 1.5000],
#         [5.2000, 0.0000, 1.3000],
#         [2.6000, 3.0000, 0.8000],
#         [2.2000, 5.0000, 1.0000]], dtype=torch.float64)
# batch labels: tensor([[ 69.1000],
#         [ 64.1000],
#         [ 81.0000],
#         [100.0000],
#         [ 65.6000],
#         [ 89.3000],
#         [ 55.7000],
#         [100.0000],
#         [ 53.2000],
#         [ 46.4000]], dtype=torch.float64)
# batch inputs: tensor([[4.9000, 0.0000, 0.7000],
#         [2.6000, 2.3000, 1.7000],
#         [4.4000, 2.9000, 1.3000],
#         [4.1000, 1.7000, 0.1000],
#         [2.9000, 2.6000, 1.8000],
#         [4.0000, 3.6000, 0.3000],
#         [2.9000, 2.5000, 2.4000],
#         [4.0000, 0.9000, 1.1000],
#         [3.9000, 1.9000, 2.4000],
#         [1.5000, 3.0000, 2.3000]], dtype=torch.float64)
# batch labels: tensor([[96.2000],
#         [45.5000],
#         [91.3000],
#         [67.5000],
#         [70.7000],
#         [91.9000],
#         [65.2000],
#         [70.7000],
#         [64.0000],
#         [57.3000]], dtype=torch.float64)
# batch inputs: tensor([[3.4000, 4.0000, 0.7000],
#         [3.1000, 1.9000, 3.7000],
#         [3.0000, 1.6000, 2.1000],
#         [3.8000, 1.4000, 1.2000],
#         [1.0000, 2.9000, 0.1000],
#         [2.8000, 1.8000, 3.4000],
#         [3.9000, 2.1000, 2.8000],
#         [3.7000, 0.6000, 1.3000],
#         [1.1000, 2.0000, 3.3000],
#         [4.3000, 2.0000, 2.8000]], dtype=torch.float64)
# batch labels: tensor([[62.0000],
#         [66.6000],
#         [70.8000],
#         [70.4000],
#         [49.9000],
#         [58.4000],
#         [77.8000],
#         [70.6000],
#         [42.6000],
#         [82.8000]], dtype=torch.float64)
# batch inputs: tensor([[0.0000, 4.6000, 1.2000],
#         [4.2000, 2.4000, 1.5000],
#         [4.4000, 1.3000, 2.4000],
#         [4.7000, 1.2000, 1.8000],
#         [3.6000, 1.3000, 2.1000],
#         [1.2000, 1.1000, 1.9000],
#         [1.8000, 3.0000, 2.0000],
#         [0.6000, 3.1000, 3.0000],
#         [2.0000, 3.8000, 0.3000],
#         [4.9000, 2.6000, 0.2000]], dtype=torch.float64)
# batch labels: tensor([[42.0000],
#         [85.9000],
#         [80.9000],
#         [83.1000],
#         [82.4000],
#         [58.6000],
#         [47.5000],
#         [18.4000],
#         [58.5000],
#         [89.3000]], dtype=torch.float64)
# batch inputs: tensor([[4.2000, 2.4000, 4.3000],
#         [6.6000, 2.8000, 2.9000],
#         [4.6000, 2.2000, 1.7000],
#         [1.1000, 2.4000, 1.8000],
#         [5.0000, 4.5000, 2.3000],
#         [2.5000, 0.2000, 0.9000],
#         [1.6000, 0.8000, 3.2000],
#         [4.2000, 2.0000, 0.4000],
#         [2.4000, 4.1000, 0.3000],
#         [5.0000, 0.8000, 2.0000]], dtype=torch.float64)
# batch labels: tensor([[ 70.7000],
#         [100.0000],
#         [ 87.3000],
#         [ 49.2000],
#         [ 98.0000],
#         [ 80.0000],
#         [ 58.2000],
#         [ 93.9000],
#         [ 67.4000],
#         [ 94.6000]], dtype=torch.float64)
# batch inputs: tensor([[6.0000, 2.9000, 2.1000],
#         [2.3000, 1.0000, 0.7000],
#         [6.2000, 3.5000, 2.3000],
#         [2.4000, 0.9000, 0.8000],
#         [1.3000, 3.8000, 3.6000],
#         [2.4000, 1.9000, 0.0000],
#         [4.9000, 1.5000, 3.5000],
#         [4.7000, 0.0000, 2.7000],
#         [4.3000, 3.4000, 0.8000],
#         [4.8000, 0.8000, 0.0000]], dtype=torch.float64)
# batch labels: tensor([[100.0000],
#         [ 72.5000],
#         [100.0000],
#         [ 78.3000],
#         [ 40.4000],
#         [ 53.9000],
#         [ 73.8000],
#         [ 67.5000],
#         [ 76.8000],
#         [ 88.0000]], dtype=torch.float64)
# batch inputs: tensor([[4.2000, 5.6000, 0.4000],
#         [3.5000, 0.0000, 1.9000],
#         [6.4000, 3.7000, 2.0000],
#         [4.4000, 2.7000, 1.0000],
#         [3.4000, 1.7000, 1.4000],
#         [1.3000, 2.2000, 1.8000],
#         [3.5000, 3.9000, 2.5000],
#         [3.6000, 3.9000, 4.2000],
#         [2.2000, 1.6000, 2.0000],
#         [1.7000, 3.3000, 1.3000]], dtype=torch.float64)
# batch labels: tensor([[78.7000],
#         [71.8000],
#         [98.8000],
#         [85.4000],
#         [70.7000],
#         [53.4000],
#         [74.5000],
#         [65.6000],
#         [65.6000],
#         [61.5000]], dtype=torch.float64)
# batch inputs: tensor([[1.8000, 2.4000, 3.3000],
#         [2.8000, 1.2000, 2.2000],
#         [3.2000, 3.0000, 3.2000],
#         [3.3000, 1.8000, 3.2000],
#         [2.8000, 2.5000, 2.7000],
#         [3.2000, 2.9000, 0.7000],
#         [1.9000, 2.3000, 1.4000],
#         [3.1000, 2.8000, 2.3000],
#         [2.7000, 2.8000, 1.4000],
#         [2.0000, 0.0000, 0.9000]], dtype=torch.float64)
# batch labels: tensor([[53.3000],
#         [75.8000],
#         [57.5000],
#         [62.2000],
#         [74.6000],
#         [67.9000],
#         [51.8000],
#         [63.7000],
#         [86.9000],
#         [54.9000]], dtype=torch.float64)
# batch inputs: tensor([[2.7000, 1.4000, 0.4000],
#         [5.6000, 3.2000, 1.0000],
#         [7.4000, 1.6000, 1.2000],
#         [3.2000, 0.2000, 0.1000],
#         [3.0000, 2.2000, 2.3000],
#         [4.8000, 3.2000, 1.6000],
#         [1.1000, 1.7000, 2.2000],
#         [1.9000, 1.7000, 2.8000],
#         [3.9000, 2.7000, 1.6000],
#         [1.0000, 2.1000, 1.0000]], dtype=torch.float64)
# batch labels: tensor([[ 57.2000],
#         [ 82.7000],
#         [100.0000],
#         [ 72.6000],
#         [ 49.1000],
#         [ 76.6000],
#         [ 59.6000],
#         [ 43.9000],
#         [ 77.8000],
#         [ 52.6000]], dtype=torch.float64)
# batch inputs: tensor([[4.9000, 0.5000, 2.1000],
#         [2.8000, 1.5000, 0.3000],
#         [2.1000, 2.8000, 1.4000],
#         [3.5000, 2.9000, 0.7000],
#         [2.9000, 4.0000, 2.9000],
#         [1.5000, 3.1000, 3.5000],
#         [0.7000, 0.7000, 1.0000],
#         [3.0000, 2.0000, 1.7000],
#         [4.4000, 0.3000, 2.1000],
#         [2.7000, 2.2000, 2.8000]], dtype=torch.float64)
# batch labels: tensor([[83.9000],
#         [71.6000],
#         [44.1000],
#         [62.9000],
#         [56.4000],
#         [44.0000],
#         [51.5000],
#         [51.3000],
#         [84.5000],
#         [53.0000]], dtype=torch.float64)
# batch inputs: tensor([[6.1000, 2.5000, 2.3000],
#         [3.0000, 3.2000, 0.3000],
#         [1.1000, 3.1000, 3.8000],
#         [5.9000, 3.5000, 0.4000],
#         [1.1000, 1.9000, 1.7000],
#         [3.7000, 3.4000, 2.0000],
#         [4.2000, 3.8000, 3.4000],
#         [3.9000, 0.7000, 0.7000],
#         [1.1000, 3.6000, 2.5000],
#         [2.3000, 1.0000, 0.4000]], dtype=torch.float64)
# batch labels: tensor([[96.5000],
#         [65.3000],
#         [45.5000],
#         [71.4000],
#         [48.3000],
#         [63.5000],
#         [67.4000],
#         [73.0000],
#         [54.6000],
#         [66.9000]], dtype=torch.float64)
# batch inputs: tensor([[5.2000, 3.2000, 2.0000],
#         [4.8000, 3.1000, 1.3000],
#         [4.1000, 2.8000, 1.6000],
#         [3.8000, 4.5000, 1.6000],
#         [3.5000, 3.2000, 0.0000],
#         [5.5000, 3.2000, 1.8000],
#         [4.8000, 2.8000, 3.1000],
#         [2.7000, 3.7000, 1.1000],
#         [3.4000, 0.1000, 0.6000],
#         [2.4000, 3.6000, 3.6000]], dtype=torch.float64)
# batch labels: tensor([[ 70.5000],
#         [100.0000],
#         [ 87.9000],
#         [ 53.5000],
#         [ 60.4000],
#         [ 77.3000],
#         [ 74.9000],
#         [ 44.3000],
#         [ 77.1000],
#         [ 48.4000]], dtype=torch.float64)
# batch inputs: tensor([[4.3000, 3.3000, 3.0000],
#         [5.3000, 1.0000, 2.2000],
#         [5.2000, 3.0000, 3.3000],
#         [2.6000, 3.1000, 0.3000],
#         [5.6000, 4.6000, 1.1000],
#         [3.9000, 2.3000, 2.1000],
#         [4.3000, 3.4000, 0.6000],
#         [3.3000, 1.4000, 1.0000],
#         [3.3000, 2.4000, 1.2000],
#         [5.4000, 4.5000, 1.0000]], dtype=torch.float64)
# batch labels: tensor([[67.3000],
#         [81.3000],
#         [87.1000],
#         [77.5000],
#         [89.7000],
#         [73.4000],
#         [77.3000],
#         [74.9000],
#         [72.5000],
#         [83.9000]], dtype=torch.float64)
# batch inputs: tensor([[6.1000, 3.5000, 0.3000],
#         [5.4000, 3.1000, 3.1000],
#         [2.0000, 1.0000, 0.1000],
#         [2.6000, 3.0000, 1.4000],
#         [5.3000, 2.9000, 1.9000],
#         [2.8000, 1.8000, 2.7000],
#         [4.7000, 3.2000, 1.9000],
#         [3.8000, 1.8000, 0.7000],
#         [3.2000, 3.2000, 0.8000],
#         [4.1000, 2.7000, 0.0000]], dtype=torch.float64)
# batch labels: tensor([[100.0000],
#         [ 77.9000],
#         [ 61.7000],
#         [ 66.7000],
#         [ 80.9000],
#         [ 64.9000],
#         [ 71.0000],
#         [ 84.2000],
#         [ 70.4000],
#         [ 87.1000]], dtype=torch.float64)
# batch inputs: tensor([[2.7000, 1.0000, 2.4000],
#         [1.5000, 2.2000, 2.3000],
#         [5.2000, 1.4000, 3.6000],
#         [2.9000, 2.7000, 2.6000],
#         [3.3000, 4.0000, 1.9000],
#         [1.0000, 3.9000, 1.0000],
#         [5.5000, 2.0000, 0.0000],
#         [3.8000, 1.2000, 2.0000],
#         [6.8000, 3.7000, 1.8000],
#         [6.1000, 1.8000, 0.5000]], dtype=torch.float64)
# batch labels: tensor([[ 57.3000],
#         [ 43.7000],
#         [ 92.0000],
#         [ 45.5000],
#         [ 43.5000],
#         [ 26.8000],
#         [ 93.7000],
#         [ 66.3000],
#         [100.0000],
#         [ 98.3000]], dtype=torch.float64)
# batch inputs: tensor([[3.4000, 2.7000, 3.4000],
#         [4.4000, 3.6000, 0.3000],
#         [3.9000, 2.1000, 2.2000],
#         [2.3000, 2.0000, 1.8000],
#         [5.5000, 3.5000, 1.1000],
#         [3.2000, 3.1000, 2.4000],
#         [5.4000, 1.8000, 3.0000],
#         [5.6000, 2.2000, 1.6000],
#         [1.2000, 3.5000, 2.0000],
#         [3.3000, 2.2000, 1.4000]], dtype=torch.float64)
# batch labels: tensor([[ 65.6000],
#         [ 87.5000],
#         [ 73.7000],
#         [ 71.4000],
#         [100.0000],
#         [ 68.5000],
#         [ 69.9000],
#         [ 84.6000],
#         [ 34.3000],
#         [ 79.5000]], dtype=torch.float64)
# batch inputs: tensor([[3.3000, 1.9000, 1.3000],
#         [4.9000, 1.0000, 2.4000],
#         [2.1000, 0.0000, 0.7000],
#         [3.6000, 3.5000, 2.1000],
#         [5.2000, 4.4000, 0.5000],
#         [5.9000, 0.0000, 3.0000],
#         [3.0000, 3.2000, 1.6000],
#         [3.1000, 2.8000, 2.0000],
#         [3.1000, 4.2000, 0.8000],
#         [3.8000, 1.2000, 1.8000]], dtype=torch.float64)
# batch labels: tensor([[67.7000],
#         [89.2000],
#         [52.5000],
#         [62.5000],
#         [74.0000],
#         [93.6000],
#         [58.4000],
#         [72.8000],
#         [64.7000],
#         [73.9000]], dtype=torch.float64)
# batch inputs: tensor([[3.2000, 3.7000, 1.2000],
#         [2.1000, 0.5000, 2.0000],
#         [2.0000, 0.2000, 0.5000],
#         [3.2000, 0.7000, 3.5000],
#         [4.0000, 1.7000, 2.0000],
#         [3.4000, 1.2000, 2.1000],
#         [5.5000, 2.2000, 0.9000],
#         [1.1000, 4.1000, 1.4000],
#         [5.8000, 1.3000, 2.2000],
#         [2.7000, 2.7000, 1.6000]], dtype=torch.float64)
# batch labels: tensor([[56.1000],
#         [62.3000],
#         [73.6000],
#         [68.3000],
#         [66.5000],
#         [68.3000],
#         [88.7000],
#         [43.7000],
#         [99.0000],
#         [36.9000]], dtype=torch.float64)
# batch inputs: tensor([[3.9000, 2.1000, 1.6000],
#         [5.2000, 4.1000, 3.8000],
#         [5.2000, 2.3000, 1.5000],
#         [2.1000, 4.9000, 1.1000],
#         [4.0000, 0.3000, 0.6000],
#         [3.5000, 2.6000, 3.2000],
#         [4.4000, 2.4000, 1.7000],
#         [4.5000, 1.3000, 4.2000],
#         [3.5000, 2.8000, 0.0000],
#         [4.7000, 0.9000, 1.0000]], dtype=torch.float64)
# batch labels: tensor([[62.8000],
#         [76.1000],
#         [82.8000],
#         [61.5000],
#         [89.5000],
#         [74.0000],
#         [76.8000],
#         [82.1000],
#         [58.7000],
#         [84.5000]], dtype=torch.float64)
